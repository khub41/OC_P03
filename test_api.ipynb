# %%
import openfoodfacts

# %%
brands = openfoodfacts.facets.get_brands()

# %%
len(brands)
# Out:
# 10000

# %%
allergs = openfoodfacts.facets.get_allergens()

# %%
len(allergs)
# Out:
# 4777

# %%
openfoodfacts.utils.download_data('csv')

# %%
import pandas as pd

# %%
generator = openfoodfacts.products.get_all_by_country("france")

# %%
pd.read_csv()
# Out:
# {'ingredients_text_fr': 'géologiques constitue un filtre naturel qui garantit son exceptionnelle pureté. EAU DE SOURCE - SOURCE FIÉE DES LOIS Composition Caractéristique (en mg/litre) 89 Bicarbonates 360 47 28 &lt;0,05 &lt;0,5 Calcium Magnésium 31 17 Sulfates Chlorures Nitrites Nitrates PH à 20°C: 7,2 Résidu à sec à 180°C: 420mg/l Sodium Potassium 2 1 Fluorures',
#  'ingredients_that_may_be_from_palm_oil_n': 0,
#  'entry_dates_tags': ['2017-06-27', '2017-06', '2017'],
#  'creator': 'kiliweb',
#  'allergens_from_ingredients': '',
#  'minerals_prev_tags': [],
#  'rev': 26,
#  'languages_hierarchy': ['en:french'],
#  'data_quality_warnings_tags': ['en:ingredients-unknown-score-above-5',
#   'en:ingredients-90-percent-unknown',
#   'en:ingredients-ingredient-tag-length-greater-than-50',
#   'en:nutrition-all-values-zero'],
#  'teams_tags': ['vendredi'],
#  'image_ingredients_thumb_url': 'https://static.openfoodfacts.org/images/products/325/039/222/8118/ingredients_fr.25.100.jpg',
# ...
